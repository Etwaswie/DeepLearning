# %% [markdown]
# # Эксперименты

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# %% [markdown]
# ## YOLOv8n на 155 классах

# %% [markdown]
# Попробуем обучить модель на исходных данных, которые содержат 155 уникальных классов.

# %%
rf = Roboflow(api_key="XF6DMw5VsWf6RtorckVT")
project = rf.workspace("mguogareva").project("russian-traffic-signs-recognition")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.216, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to russian-traffic-signs-recognition-1 in yolov8:: 100%|██████████| 4792/4792 [00:01<00:00, 4602.05it/s]

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 72.5MB/s]

# %%
model.train(data='/content/russian-traffic-signs-recognition-1/data.yaml', epochs=5, device=0)
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Реузльтаты оказались низкими, посколькую есть явный перекос в сторону нескольких классов, при этом для других имеется всего несколько изображений.

# %% [markdown]
# ## YOLOv8n на 8 классах

# %% [markdown]
# Все дорожные знаки по ГОСТу делятся на 8 подгрупп. Возьмем за основу эту идею и сгруппируем 155 классов в 8.

# %%
rf = Roboflow(api_key="XF6DMw5VsWf6RtorckVT")
project = rf.workspace("mguogareva").project("russian-traffic-signs-recognition")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.216, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to russian-traffic-signs-recognition-1 in yolov8:: 100%|██████████| 4792/4792 [00:02<00:00, 1991.45it/s]

# %%
import json

with open('/content/class_map.json', 'r') as f:
    class_map = json.load(f)

# %%
groups = class_map['groups']
sorted(groups)
# Out:
# ['additional_information',
#  'information',
#  'prescription',
#  'priority',
#  'prohibition',
#  'service',
#  'special_regulation',
#  'warning']

# %%
group_map = {g: i for i, g in enumerate(sorted(groups))}
group_map
# Out:
# {'additional_information': 0,
#  'information': 1,
#  'prescription': 2,
#  'priority': 3,
#  'prohibition': 4,
#  'service': 5,
#  'special_regulation': 6,
#  'warning': 7}

# %%
new_class_map = {}
for i, k in enumerate(class_map['label_map'].keys()):
    new_class_map[i] = group_map[class_map['label_map'][k]]

# %%
import os

root_dirs = ['/content/russian-traffic-signs-recognition-1/train/labels',
             '/content/russian-traffic-signs-recognition-1/valid/labels',
             '/content/russian-traffic-signs-recognition-1/test/labels']
for root in root_dirs:
    labels = os.listdir(root)
    for l in labels:
        label_file = root + '/' + l
        with open(label_file, 'r') as f:
            annot = f.readlines()

        new_annot = []
        for a in annot:
            a = a.rstrip().split(' ')
            lbl = new_class_map[int(a[0])]
            new_annot.append(f"{lbl} {' '.join(a[1:])}")
        with open(label_file, 'w') as f:
            for a in new_annot:
                f.write(a + '\n')

# %%
model_2 = YOLO('yolov8n.pt')

# %%
model.train(data='/content/russian-traffic-signs-recognition-1/data_8_classes.yaml', epochs=5, device=0)
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Результаты в разы лучше. Продолжим эксперименты, но теперь постараемся подобрать оптимальные гиперпараметры.

# %%
def objective(trial):
    data_path = '/content/russian-traffic-signs-recognition-1/data_8_classes.yaml'
    model = YOLO('yolov8n.pt')

    batch = trial.suggest_categorical("batch", [16, 32, 64])
    lr = trial.suggest_categorical("lr0", [0.01, 0.001, 0.0001])
    optimizer_type = trial.suggest_categorical("optimizer", ["Adam", "AdamW", "RMSProp"])

    model.train(data=data_path, epochs=5, device=0)

# %%
model = YOLO('yolov8n.pt')
model.tune(data='/content/russian-traffic-signs-recognition-1/data_8_classes.yaml',
           epochs=5, iterations=20, optimizer='Adam',
           plots=False, save=True, val=True)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 78.0MB/s]
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/20 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 1/20 iterations complete ✅ (257.17s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.03273 observed at iteration 1
# ...

# %%
model = YOLO('/content/runs/detect/tune/weights/best.pt')
model.val(data='/content/russian-traffic-signs-recognition-1/data_8_classes.yaml', device=0)
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/russian-traffic-signs-recognition-1/valid/labels.cache... 478 images, 0 backgrounds, 0 corrupt: 100%|██████████| 478/478 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 30/30 [00:06<00:00,  4.47it/s]
#                    all        478        493      0.295      0.138     0.0622     0.0363
#                warning        478         77     0.0582      0.455     0.0799     0.0447
#               priority        478         29          1          0     0.0312     0.0174
#            prohibition        478         46     0.0322     0.0652     0.0359     0.0184
#           prescription        478         39          1          0      0.104     0.0663
# ...
